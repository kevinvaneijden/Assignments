# %% [markdown]
# # Exam
#
# In this exam, we will work with the "frequently requested health data” from the OECD.
# Your task is to compute a simple “efficiency score” and make three plots.
#
#
# You will earn a higher grade if you provide nicer graphs.

# %% [markdown]
# **Name:** Kevin van Eijden <br>
# **Student number:** (2000214)

# %% [markdown]
# Now you need to call the libaries
#
# * ggplot2
# * dplyr

# %%
library(ggplot2)
library(dplyr)
# Out:
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# Now you have to read the de data that we have cleaned during tutorial 3. The csv file is called oecddata.csv

# %%
oecd <- read.csv2("oecddata.csv", sep=";")

# %% [markdown]
# To see how the data look like, use the command:
#
# head(oecd)
#
# With the command
#
# oecd
#
#
# You can see the dataset in total.

# %%
head(oecd);
oecd
# Out:
#   X Country   Year Cost     LE
# 1 1 Australia 2005 2842.132 80.9
# 2 2 Australia 2006 3023.098 81.1
# 3 3 Australia 2007 3196.226 81.4
# 4 4 Australia 2008 3310.171 81.5
# 5 5 Australia 2009 3564.405 81.6
# 6 6 Australia 2010 3607.341 81.8
#     X   Country        Year Cost      LE
# 1    1  Australia      2005 2842.132  80.9
# 2    2  Australia      2006 3023.098  81.1
# 3    3  Australia      2007 3196.226  81.4
# 4    4  Australia      2008 3310.171  81.5
# 5    5  Australia      2009 3564.405  81.6
# 6    6  Australia      2010 3607.341  81.8
# 7    7  Australia      2011 3794.087  82.0
# 8    8  Australia      2012 3807.682  82.1
# 9    9  Australia      2013 4176.853  82.2
# 10  10  Australia      2014 4206.852  82.4
# 11  11  Australia      2015 4420.436    NA
# 12  12  Austria        2005 3324.079  79.4
# 13  13  Austria        2006 3567.649  80.0
# 14  14  Austria        2007 3718.739  80.3
# 15  15  Austria        2008 3964.849  80.5
# ...

# %% [markdown]
# ## Graphs

# %% [markdown]
# To make the graphs we need to make selections of the data. Please use "dplyr" (commands "select" and "filter") and the "pipe". The first assignment is to make a scatterplot using "ggplot". The graph contains data for all countries for the year 2014. Therefore make a dataframe with dplyr first, called "graph1" with the required data.
# Then, make a scatterplot with "Cost" on the x-axis and "LE" on the y-axis. You have to add a regression line with a shaded area for the confidence interval.

# %%
graph1 <- data.frame(oecd) %>%
    select(Country, Year, Cost, LE) %>%
    filter(Year == 2014)
graph1
# Out:
#    Country         Year Cost      LE
# 1  Australia       2014 4206.8516 82.4
# 2  Austria         2014 4895.9992 81.6
# 3  Belgium         2014 4522.0450 81.4
# 4  Canada          2014 4491.7648   NA
# 5  Chile           2014 1688.5233 79.0
# 6  Czech Republic  2014 2386.3385 78.9
# 7  Denmark         2014 4857.0285 80.8
# 8  Estonia         2014 1724.5100 77.2
# 9  Finland         2014 3870.4000 81.3
# 10 France          2014 4366.9864 82.8
# 11 Germany         2014 5119.2146 81.2
# 12 Greece          2014 2220.1065 81.5
# 13 Hungary         2014 1796.6034 75.9
# 14 Iceland         2014 3896.9251 82.9
# 15 Ireland         2014 5001.3220 81.4
# 16 Israel          2014 2547.4010 82.2
# 17 Italy           2014 3206.8286 83.2
# 18 Japan           2014 4152.3727 83.7
# 19 Korea           2014 2361.4400 82.2
# 20 Latvia          2014 1295.0128 74.3
# 21 Luxembourg      2014 6682.2370 82.3
# 22 Mexico          2014 1035.3389 74.8
# 23 Netherlands     2014 5276.6003 81.8
# ...

# %%
ggplot(graph1, aes(x=Cost, y=LE))+ geom_point() + geom_smooth(method=lm)
# Out:
# Warning message:
# "Removed 1 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 1 rows containing missing values (geom_point)."
# plot without title

# %% [markdown]
# **Explanation:** <br>
# I plotted graph1 with the function ggplot. The Costs are on the x-axis and the LE is on the y-axis. The warning is there because Canada hasn't got a valid LE value.

# %% [markdown]
# The second assignment is to make a line graph. You will use the years 2005-2015 for 5 countries (you can choose your own countries). Make a new dataframe called graph2 with the required data. Then, make a line graph with "Year"  and "Cost" on the y-axis. There should be coloured lines per country and a legend attached.

# %%
graph2 <- data.frame(oecd) %>%
    select(Country, Year, Cost) %>%
    filter(Country %in% c("Estonia", "Iceland", "Korea", "Netherlands", "Turkey"))
graph2
# Out:
#    Country     Year Cost
# 1  Estonia     2005  820.7244
# 2  Estonia     2006  949.1905
# 3  Estonia     2007 1098.0087
# 4  Estonia     2008 1284.4079
# 5  Estonia     2009 1319.5699
# 6  Estonia     2010 1334.1851
# 7  Estonia     2011 1392.1765
# 8  Estonia     2012 1502.9345
# 9  Estonia     2013 1623.1936
# 10 Estonia     2014 1724.5100
# 11 Estonia     2015 1824.4642
# 12 Iceland     2005 3294.4734
# 13 Iceland     2006 3276.3176
# 14 Iceland     2007 3375.6701
# 15 Iceland     2008 3628.0346
# 16 Iceland     2009 3624.4513
# 17 Iceland     2010 3405.9865
# 18 Iceland     2011 3420.6305
# 19 Iceland     2012 3506.4164
# 20 Iceland     2013 3739.4503
# 21 Iceland     2014 3896.9251
# 22 Iceland     2015 4011.9968
# 23 Korea       2005 1220.0809
# 24 Korea       2006 1406.6213
# 25 Korea       2007 1566.6353
# 26 Korea       2008 1662.9686
# 27 Korea       2009 1791.2895
# 28 Korea       2010 1951.3258
# 29 Korea       2011 2029.6636
# 30 Korea       2012 2131.9334
# ...

# %%
graph2$Country <- as.factor(graph2$Country)
ggplot(graph2, aes(x=Year, y=Cost, col=Country))+ geom_line(size=1)
# Out:
# plot without title

# %% [markdown]
# **Explanation:** <br>
# Here I plotted graph2, with on the x-axis the years and on the y-axis the costs. I also created a collom with the country's I used. And ofcourse I used geom_line because i needed lines.

# %% [markdown]
# ## Efficiency scores
#
# The last assignment is to compute simple effiency scores. We will use the year 2014 for all countries (i.e. the dataframe "graph1").
# Make a new dateframe called "eff" (using graph1). Please use the "pipe" to execute to following steps:
# Select all the variables except the NA's (hint: use na.omit) and create a new column called "Ratio" with mutate. Ratio is defined as "Cost/LE" (cost per output).
# Create a new column called "Score" with mutate. Score is the ratio per country divided by the lowest ratio in the dataframe.
# To complete this dataframe order the dataset using "arrange" based on score (i.e. lowest Score first).
#
#
# Finally make a bar chart using ggplot. Countries should be on the x-axis and "Score" on the y-axis.
#
#
#
# You can earn extra points if you are able to order the graph based on scores (lowest first, highest last), if you are able to make the x-axis readable, make the bar of the Netherlands red and the other bars blue and/or change the name of the y-axis to "Efficiency scores according to [your name]"
#
#
# The figure should like this:
#
# ![My Figure](eff.png)

# %%
eff <- graph1 %>%
    filter(!is.na(LE)) %>%
    mutate(Ratio = Cost / LE) %>%
    mutate(Score = min(Ratio) / Ratio) %>%
    arrange(Score)
eff
# Out:
#    Country         Year Cost      LE   Ratio     Score
# 1  United States   2014 9024.2064 78.8 114.52039 0.1108515
# 2  Switzerland     2014 6786.5657 83.3  81.47138 0.1558186
# 3  Luxembourg      2014 6682.2370 82.3  81.19365 0.1563516
# 4  Norway          2014 6080.9980 82.2  73.97808 0.1716016
# 5  Netherlands     2014 5276.6003 81.8  64.50612 0.1967992
# 6  Germany         2014 5119.2146 81.2  63.04451 0.2013618
# 7  Sweden          2014 5065.1613 82.3  61.54509 0.2062675
# 8  Ireland         2014 5001.3220 81.4  61.44130 0.2066160
# 9  Denmark         2014 4857.0285 80.8  60.11174 0.2111859
# 10 Austria         2014 4895.9992 81.6  59.99999 0.2115793
# 11 Belgium         2014 4522.0450 81.4  55.55338 0.2285145
# 12 France          2014 4366.9864 82.8  52.74138 0.2406982
# 13 Australia       2014 4206.8516 82.4  51.05402 0.2486533
# 14 Japan           2014 4152.3727 83.7  49.61019 0.2558901
# 15 United Kingdom  2014 3971.3940 81.4  48.78862 0.2601991
# ...

# %%
ggplot(eff, aes(x= reorder(Country, Score), y =Score, fill=Country)) + 
    guides(fill=FALSE) + geom_bar(stat="identity") + xlab("Country") +
    ylab("Efficiency scores according to Kevin") + theme(axis.text.x= element_text(angle= 45, hjust= 1)) +
    scale_fill_manual(values = c(rep("Blue",21),rep("Red",1),rep("Blue",12)))
# Out:
# plot without title

# %% [markdown]
# **Explanation:** <br>
# First I created a dataframe called "eff". Here i calculated the Score dividing the ratio by the lowest ratio in the dataframe. I calculated the ratio dividing the Cost by LE. <br>
#
# Then I used ggplot to plot the graph. Ofcourse this was a bar chart so I used geom_bar. On the x-axis I put the Country's reordered by score and on the y-axis I put the score. I put guides(fill=false) because otherwise I got a legend attached. xlab and ylab are for the titles of the axes. Theme is for the text and to rotate the text. At last I made the bar of the Netherlands red. I think I did this a little laborious, but I couldn't find a better way.
